# %%
# https://github.com/sharebook-kr/pyupbit
# https://blog.naver.com/zacra/223711423614

import pyupbit
import time
import os
from dotenv import load_dotenv
# Out:
# /Users/kimdonghyeon/2025/개발/Bitcoin-Auto-Bot /.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## 모든 암호화폐 목록

# %%
# 모든 암호화폐 목록
# print(pyupbit.get_tickers())

# 원화 거래만 하기 위해 원화 마켓 코인만 출력
coins = pyupbit.get_tickers(fiat="KRW")
for coin in coins:
    print(f"{coin} - {pyupbit.get_current_price(coin)}")
    time.sleep(0.05) # 초당 10회: Upbit Quotation API 권장치
# Out:
# KRW-WAXP - 29.1
# KRW-CARV - 397.0
# KRW-LSK - 581.0
# KRW-BORA - 132.0
# KRW-PUNDIX - 425.0
# KRW-BAT - 210.0
# KRW-HUNT - 357.0
# KRW-PENGU - 46.7
# KRW-FIL - 3279.0
# KRW-BEAM - 9.69
# KRW-WAVES - 1395.0
# KRW-USDC - 1394.0
# KRW-MOVE - 183.0
# KRW-AERGO - 161.0
# KRW-USDT - 1396.0
# KRW-BOUNTY - 64.3
# KRW-KAITO - 1604.0
# KRW-LPT - 8450.0
# KRW-BLAST - 4.13
# KRW-DKA - 21.6
# KRW-ANKR - 21.8
# KRW-ALGO - 335.0
# KRW-SHIB - 0.017
# KRW-UNI - 12850.0
# KRW-TOKAMAK - 1878.0
# KRW-DOGE - 286.0
# KRW-PEPE - 0.0147
# KRW-HBAR - 342.0
# KRW-BCH - 783000.0
# KRW-NEWT - 486.0
# KRW-SEI - 400.0
# KRW-BONK - 0.0357
# KRW-JST - 47.1
# KRW-AAVE - 358700.0
# KRW-JTO - 2344.0
# KRW-JUP - 663.0
# KRW-FLOW - 508.0
# KRW-ALT - 44.5
# KRW-LAYER - 837.0
# KRW-TRX - 454.0
# KRW-POWR - 233.0
# KRW-ATOM - 5820.0
# KRW-ARKM - 651.0
# KRW-CRO - 192.0
# KRW-NXPC - 1238.0
# KRW-A - 704.0
# KRW-TRUMP - 12300.0
# KRW-G - 16.7
# KRW-CELO - 432.0
# KRW-CTC - 902.0
# KRW-ANIME - 22.9
# KRW-APT - 5955.0
# KRW-MOCA - 108.0
# KRW-AHT - 5.41
# KRW-EGLD - 19690.0
# KRW-ERA - 1413.0
# KRW-NEO - 8250.0
# KRW-ETC - 28050.0
# KRW-IOTA - 257.0
# KRW-IOST - 5.06
# KRW-AKT - 1645.0
# KRW-COW - 499.0
# KRW-VIRTUAL - 1705.0
# KRW-ETH - 5066000.0
# KRW-IQ - 5.11
# KRW-NEAR - 3460.0
# KRW-RVN - 18.9
# KRW-AGLD - 943.0
# KRW-ID - 224.0
# KRW-WAL - 537.0
# KRW-PENDLE - 5460.0
# KRW-BLUR - 118.0
# KRW-AWE - 70.8
# KRW-THETA - 1077.0
# KRW-AXL - 470.0
# KRW-HP - 65.4
# KRW-SAND - 375.0
# KRW-WCT - 417.0
# KRW-AXS - 3124.0
# KRW-ARDR - 127.0
# KRW-AQT - 1591.0
# KRW-ME - 1029.0
# KRW-SONIC - 295.0
# KRW-ARB - 540.0
# KRW-POL - 280.0
# KRW-CVC - 131.0
# KRW-T - 23.3
# KRW-W - 106.0
# KRW-ARK - 592.0
# KRW-HYPER - 547.0
# KRW-ATH - 44.7
# KRW-TAIKO - 592.0
# KRW-AVAX - 30530.0
# KRW-IMX - 704.0
# KRW-SC - 5.0
# KRW-INJ - 18000.0
# KRW-MVL - 4.63
# KRW-HIVE - 303.0
# KRW-CBK - 842.0
# KRW-OM - 330.0
# KRW-XLM - 546.0
# KRW-OP - 910.0
# KRW-SAFE - 586.0
# KRW-GLM - 353.0
# KRW-POKT - 55.5
# KRW-KNC - 581.0
# KRW-AUCTION - 13400.0
# KRW-DRIFT - 709.0
# KRW-FCT2 - 43.3
# KRW-MTL - 999.0
# KRW-VET - 31.7
# KRW-QTUM - 2918.0
# KRW-TT - 4.07
# KRW-LINK - 23050.0
# KRW-XRP - 4107.0
# KRW-CHZ - 53.3
# KRW-ASTR - 32.2
# KRW-STORJ - 367.0
# KRW-ENA - 811.0
# KRW-MANA - 386.0
# KRW-GRS - 432.0
# KRW-PYTH - 157.0
# KRW-UXLINK - 453.0
# KRW-ENS - 36150.0
# KRW-GRT - 129.0
# KRW-XTZ - 1069.0
# KRW-CKB - 7.72
# KRW-KAVA - 534.0
# KRW-ZRO - 2377.0
# KRW-RAY - 3757.0
# KRW-ONDO - 1250.0
# KRW-ZRX - 327.0
# KRW-GMT - 61.0
# KRW-TFUEL - 53.5
# KRW-MASK - 1710.0
# KRW-COMP - 61550.0
# KRW-ZETA - 256.0
# KRW-TIA - 2319.0
# KRW-ADA - 1006.0
# KRW-ELF - 292.0
# KRW-STEEM - 186.0
# KRW-SOPH - 54.9
# KRW-MED - 8.21
# KRW-1INCH - 341.0
# KRW-MEW - 4.26
# KRW-ORBS - 25.7
# KRW-RENDER - 5055.0
# KRW-STG - 221.0
# KRW-ORCA - 3070.0
# KRW-BERA - 2558.0
# KRW-SIGN - 98.3
# KRW-VANA - 5925.0
# KRW-DOT - 5080.0
# KRW-STRIKE - 16490.0
# KRW-MBL - 3.153
# KRW-BIGTIME - 80.8
# KRW-SNT - 39.7
# KRW-SOL - 234900.0
# KRW-QKC - 10.7
# KRW-META - 30.8
# KRW-SAHARA - 116.0
# KRW-MLK - 219.0
# KRW-SXP - 251.0
# KRW-VTHO - 2.58
# KRW-OMNI - 6230.0
# KRW-MINA - 254.0
# KRW-GAS - 4132.0
# KRW-MNT - 1023.0
# KRW-MOC - 94.2
# KRW-MOODENG - 226.0
# KRW-XEC - 0.0286
# KRW-ZIL - 15.8
# KRW-GAME2 - 5.05
# KRW-STX - 986.0
# KRW-BSV - 36810.0
# KRW-SUI - 4885.0
# KRW-SYRUP - 567.0
# KRW-BTC - 160078000.0
# KRW-ONG - 241.0
# KRW-BTT - 0.000933
# KRW-ONT - 185.0
# KRW-DEEP - 197.0
# KRW-STRAX - 66.7
# KRW-ICX - 180.0
# KRW-POLYX - 187.0

# %% [markdown]
# ## 시장가 매수

# %%
# .env 파일에서 환경변수 로드
load_dotenv()
Access_Key = os.environ.get('ACCESS_KEY')
Secret_Key = os.environ.get('SECRET_KEY')

print(f"Access Key: {Access_Key}")
print(f"Secret Key: {Secret_Key}")

upbit = pyupbit.Upbit(Access_Key, Secret_Key)
upbit.buy_market_order("KRW-BTC", 5000)
# Out:
# Access Key: 38kHPbF1a3Jmh5TA8uneFQVoiexwBupN6GfPHp5a
# Secret Key: gYqHxPtaBV0tCOvhc0x0tC30VuicYjvyVQ8IExi7
# {'uuid': 'a0b37a32-01fb-4c36-bd94-aa483d1b7d39',
#  'side': 'bid',
#  'ord_type': 'price',
#  'price': '5000',
#  'state': 'wait',
#  'market': 'KRW-BTC',
#  'created_at': '2025-08-01T16:37:10+09:00',
#  'reserved_fee': '2.5',
#  'remaining_fee': '2.5',
#  'paid_fee': '0',
#  'locked': '5002.5',
#  'prevented_locked': '0',
#  'executed_volume': '0',
#  'trades_count': 0}
